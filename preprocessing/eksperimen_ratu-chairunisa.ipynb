# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    Dataset dapat diperoleh dari berbagai sumber, seperti public repositories (*Kaggle*, *UCI ML Repository*, *Open Data*) atau data primer yang Anda kumpulkan sendiri.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn mlflow keras tensorflow
# Out:
# Requirement already satisfied: pandas in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (2.3.2)
# Requirement already satisfied: matplotlib in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (3.10.5)
# Requirement already satisfied: seaborn in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (1.7.1)
# Requirement already satisfied: mlflow in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (2.19.0)
# Requirement already satisfied: keras in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (3.11.3)
# Requirement already satisfied: tensorflow in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (2.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\62852\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mlflow-skinny==2.19.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (2.19.0)
# Requirement already satisfied: Flask<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (3.8.2)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: waitress<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (0.64.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (1.36.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (5.29.5)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow) (0.5.3)
# Requirement already satisfied: Mako in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.15.0)
# Requirement already satisfied: colorama in c:\users\62852\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->mlflow-skinny==2.19.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (2.40.3)
# Requirement already satisfied: pywin32>=304 in c:\users\62852\appdata\roaming\python\python312\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.19.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.19.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.19.0->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.19.0->mlflow) (0.57b0)
# Requirement already satisfied: six>=1.5 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow) (0.6.1)
# Requirement already satisfied: greenlet>=1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: absl-py in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: rich in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from keras) (14.1.0)
# Requirement already satisfied: namex in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from keras) (0.5.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: setuptools in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# In a notebook cell:
# !pip install mlflow==2.19.0
# Out:
# Requirement already satisfied: mlflow==2.19.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (2.19.0)
# Requirement already satisfied: mlflow-skinny==2.19.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (2.19.0)
# Requirement already satisfied: Flask<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (3.1.2)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (1.16.5)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (3.8.2)
# Requirement already satisfied: matplotlib<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (3.10.5)
# Requirement already satisfied: numpy<3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (2.3.2)
# Requirement already satisfied: pandas<3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (2.3.2)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (1.7.1)
# Requirement already satisfied: scipy<2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (1.16.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (2.0.43)
# Requirement already satisfied: waitress<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow==2.19.0) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (0.64.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (1.36.0)
# Requirement already satisfied: packaging<25 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (5.29.5)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from mlflow-skinny==2.19.0->mlflow==2.19.0) (0.5.3)
# Requirement already satisfied: Mako in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from alembic!=1.10.0,<2->mlflow==2.19.0) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from alembic!=1.10.0,<2->mlflow==2.19.0) (4.15.0)
# Requirement already satisfied: colorama in c:\users\62852\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (2.40.3)
# Requirement already satisfied: pywin32>=304 in c:\users\62852\appdata\roaming\python\python312\site-packages (from docker<8,>=4.0.0->mlflow==2.19.0) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from docker<8,>=4.0.0->mlflow==2.19.0) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow==2.19.0) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow==2.19.0) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow==2.19.0) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from Flask<4->mlflow==2.19.0) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.19.0->mlflow==2.19.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.19.0->mlflow==2.19.0) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from graphene<4->mlflow==2.19.0) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from graphene<4->mlflow==2.19.0) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\62852\appdata\roaming\python\python312\site-packages (from graphene<4->mlflow==2.19.0) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib<4->mlflow==2.19.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib<4->mlflow==2.19.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib<4->mlflow==2.19.0) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib<4->mlflow==2.19.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib<4->mlflow==2.19.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from matplotlib<4->mlflow==2.19.0) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (0.57b0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas<3->mlflow==2.19.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas<3->mlflow==2.19.0) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==2.19.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow==2.19.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow==2.19.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow==2.19.0) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow==2.19.0) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from scikit-learn<2->mlflow==2.19.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from scikit-learn<2->mlflow==2.19.0) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.19.0) (3.2.4)

# %%
import tensorflow as tf
import mlflow.tensorflow

print(tf.__version__)  # seharusnya 2.19.0
mlflow.tensorflow.autolog()
# Out:
# 2025/08/31 16:16:45 WARNING mlflow.utils.autologging_utils: MLflow tensorflow autologging is known to be compatible with 2.7.4 <= tensorflow <= 2.18.0, but the installed version is 2.20.0. If you encounter errors during autologging, try upgrading / downgrading tensorflow to a compatible version, or try upgrading MLflow.
# 2.20.0

# %%
import mlflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import os

#import google.protobuf

from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
# Install dependencies as needed:
# %pip install kagglehub[pandas-datasets]

import kagglehub
from kagglehub import KaggleDatasetAdapter

# Download latest version
path = kagglehub.dataset_download("muhamedumarjamil/crypto-and-gold-prices-dataset-20152025")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub[pandas-datasets] in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from kagglehub[pandas-datasets]) (24.2)
# Requirement already satisfied: pyyaml in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from kagglehub[pandas-datasets]) (6.0.2)
# Requirement already satisfied: requests in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from kagglehub[pandas-datasets]) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from kagglehub[pandas-datasets]) (4.67.1)
# Requirement already satisfied: pandas in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from kagglehub[pandas-datasets]) (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\62852\appdata\roaming\python\python312\site-packages (from pandas->kagglehub[pandas-datasets]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from python-dateutil>=2.8.2->pandas->kagglehub[pandas-datasets]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests->kagglehub[pandas-datasets]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests->kagglehub[pandas-datasets]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests->kagglehub[pandas-datasets]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\62852\anaconda3\envs\smsml_ratu_chairunisa\lib\site-packages (from requests->kagglehub[pandas-datasets]) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\62852\appdata\roaming\python\python312\site-packages (from tqdm->kagglehub[pandas-datasets]) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Path to dataset files: C:\Users\62852\.cache\kagglehub\datasets\muhamedumarjamil\crypto-and-gold-prices-dataset-20152025\versions\1

# %%
df = pd.read_csv('D:\SMSML_Ratu_Chairunisa\crypto.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\62852\AppData\Local\Temp\ipykernel_15820\2358320100.py:1: SyntaxWarning: invalid escape sequence '\S'
#   df = pd.read_csv('D:\SMSML_Ratu_Chairunisa\crypto.csv')
#          Date  Bitcoin (USD)  Ethereum (USD)  Gold (USD per oz)  \
# 0  2015-01-01    1099.671415      102.760097        1199.071870
# 1  2015-01-02    1135.844985      110.806193        1201.928708
# 2  2015-01-03    1250.613839      116.286699        1201.829678
# 3  2015-01-04    1452.916825      118.393314        1199.858272
# 4  2015-01-05    1479.501487      128.322865        1200.014190
#
#    Cardano (ADA)  Binance Coin (BNB)  Ripple (XRP)  Dogecoin (DOGE)  \
# 0       0.490443           19.915520      0.209481         0.045930
# 1       0.526877           20.271863      0.222041         0.054818
# 2       0.520009           19.974075      0.229863         0.049255
# 3       0.563435           19.942816      0.243224         0.047298
# 4       0.644235           20.201745      0.238137         0.044584
#
#    Solana (SOL)
# 0      5.987009
# 1      5.687508
# 2      7.050012
# 3      7.903578
# 4      8.140522

# %%
# Date ke datetime & set index
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %%
# Visualisasi Tren Harga
plt.figure(figsize=(14, 7))
symbols_to_plot = ["Bitcoin (USD)", "Ethereum (USD)", "Gold (USD per oz)"]
for symbol in symbols_to_plot:
    plt.plot(
        df.index,
        df[symbol],
        label=symbol
    )
plt.title("Tren Harga Close Bitcoin, Etherum, & Emas (2015–2025)")
plt.xlabel("Tahun")
plt.ylabel("Harga (USD)")
plt.legend()
plt.show()

# %%
# Visualisasi Tren Harga
plt.figure(figsize=(14, 7))
symbols_to_plot = ["Cardano (ADA)", "Binance Coin (BNB)", "Ripple (XRP)", "Dogecoin (DOGE)", "Solana (SOL)"]
for symbol in symbols_to_plot:
    plt.plot(
        df.index,
        df[symbol],
        label=symbol
    )
plt.title("Tren Harga Close Kripto Lainnya (2015–2025)")
plt.xlabel("Tahun")
plt.ylabel("Harga (USD)")
plt.legend()
plt.show()

# %%
# Calculate daily returns
daily_returns = df.pct_change().dropna()

# Loop to display the daily returns plot for each crypto
for column in daily_returns.columns:
    plt.figure(figsize=(12, 5))
    plt.plot(daily_returns.index, daily_returns[column], label=f"{column}", color="tab:red")

    plt.title(f"Daily Returns - {column}", fontsize=14)
    plt.xlabel("Tahun")
    plt.ylabel("Return Harian")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %%
correlation_matrix = daily_returns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Korelasi Daily Returns Antar Kripto dan Emas")
plt.show()

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
# Melihat missing value
df.isnull().sum()
# Out:
# Bitcoin (USD)         0
# Ethereum (USD)        0
# Gold (USD per oz)     0
# Cardano (ADA)         0
# Binance Coin (BNB)    0
# Ripple (XRP)          0
# Dogecoin (DOGE)       0
# Solana (SOL)          0
# dtype: int64

# %%
# Melihat data duplikat
print("Jumlah data duplikat:", df.duplicated().sum())
# Out:
# Jumlah data duplikat: 0

# %%
df.describe()
# Out:
#        Bitcoin (USD)  Ethereum (USD)  Gold (USD per oz)  Cardano (ADA)  \
# count    3858.000000     3858.000000        3858.000000    3858.000000
# mean   103295.091119    18646.484019        2219.843587      41.150393
# std     59086.885281    10770.200525         540.896499      23.796932
# min      1099.671415      102.760097        1199.071870       0.490443
# 25%     51775.591274     9183.157088        1766.802440      20.141836
# 50%    105376.860438    18646.902925        2256.204837      40.974391
# 75%    154587.897710    27888.634698        2697.102069      62.185396
# max    201506.238999    37333.366859        3119.461819      81.532909
#
#        Binance Coin (BNB)  Ripple (XRP)  Dogecoin (DOGE)  Solana (SOL)
# count         3858.000000   3858.000000      3858.000000   3858.000000
# mean           623.130826     19.308745         3.931897    906.933311
# std            348.628727     10.848451         2.257275    532.415463
# min             19.915520      0.209481         0.044584      5.687508
# 25%            313.600483      9.928481         2.004034    468.198474
# 50%            631.888911     19.377614         3.767681    884.089973
# 75%            928.463897     29.273697         5.929516   1361.069455
# max           1219.517885     37.667654         7.971408   1866.601974

# %%
def normalize_series(data, min, max):
    data = data - min
    data = data / max
    return data
data = df.values
data = normalize_series(data, data.min(axis=0), data.max(axis=0))

# %%
selected_columns = ["Bitcoin (USD)", "Ethereum (USD)", "Gold (USD per oz)", "Cardano (ADA)", "Binance Coin (BNB)", "Ripple (XRP)", "Dogecoin (DOGE)", "Solana (SOL)"]
N_FEATURES = len(selected_columns)
print("jumlah fitur yang digunakan:", N_FEATURES)
# Out:
# jumlah fitur yang digunakan: 8

# %%
def windowed_dataset(series, batch_size, n_past=24, n_future=24, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=n_past + n_future, shift=shift, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.map(lambda w: (w[:n_past], w[n_past:]))
    return ds.batch(batch_size).prefetch(1)

# %%
# Split data into training and validation sets
train_size = int(len(data) * 0.8)
x_train, x_valid = data[0:train_size], data[train_size:]

# %%
BATCH_SIZE = 32
N_PAST = 30
N_FUTURE = 30
SHIFT = 1
# Kode untuk membuat windowed datasets
train_set = windowed_dataset(series=x_train, batch_size=BATCH_SIZE,
                                 n_past=N_PAST, n_future=N_FUTURE,
                                 shift=SHIFT)
valid_set = windowed_dataset(series=x_valid, batch_size=BATCH_SIZE,
                                 n_past=N_PAST, n_future=N_FUTURE,
                                 shift=SHIFT)

# %% [markdown]
# # Modelling

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(N_PAST, N_FEATURES)),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(N_FUTURE * N_FEATURES), # Change units to N_FUTURE * N_FEATURES
    tf.keras.layers.Reshape((N_FUTURE, N_FEATURES))
])
# Out:
# c:\Users\62852\anaconda3\envs\SMSML_Ratu_Chairunisa\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs={}):
            if (logs.get('mae') < 0.055 and logs.get('val_mae') < 0.055):
                self.model.stop_training = True

callbacks = myCallback()

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss='mae',
                  optimizer= optimizer,
                  metrics=["mae"])

# %%
model.fit(train_set,
          validation_data=(valid_set),
          epochs=100,
          callbacks=callbacks,
          verbose=1
    )
# Out:
# 2025/08/31 16:16:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd48abf2fd6ef48e48bb34d7f394c1351', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# Epoch 1/100
#      95/Unknown 4s 13ms/step - loss: 0.0720 - mae: 0.0720
# 2025/08/31 16:16:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\62852\anaconda3\envs\SMSML_Ratu_Chairunisa\Lib\site-packages\keras\src\trainers\epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset."
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0595 - mae: 0.0595 - val_loss: 0.0962 - val_mae: 0.0962
# Epoch 2/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0401 - mae: 0.0401 - val_loss: 0.0931 - val_mae: 0.0931
# Epoch 3/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0358 - mae: 0.0358 - val_loss: 0.0905 - val_mae: 0.0905
# Epoch 4/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0805 - val_mae: 0.0805
# Epoch 5/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0110 - mae: 0.0110 - val_loss: 0.0660 - val_mae: 0.0660
# Epoch 6/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0194 - mae: 0.0194 - val_loss: 0.0583 - val_mae: 0.0583
# Epoch 7/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0091 - mae: 0.0091 - val_loss: 0.0387 - val_mae: 0.0387
# 2025/08/31 16:17:06 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during tensorflow autologging: 'myCallback' object is not iterable

# %%
train_pred = model.predict(train_set)
train_pred[0][0]
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# array([0.06293889, 0.0595896 , 0.06485765, 0.06280822, 0.0524086 ,
#        0.07818939, 0.04719829, 0.05290902], dtype=float32)

# %%
crypto_names = ["BTC", "ETH", "GOLD", "ADA", "BNB", "XRP", "DOGE", "SOL"]
train_pred = model.predict(train_set)
predictions = train_pred[0]   # shape (N_FUTURE, n_crypto)

# Data tanggal
last_date = pd.to_datetime("2025-07-24")   # data terakhir
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1),
                             periods=len(predictions), freq="D")

# Visualisasi Subplot
n_crypto = len(crypto_names)
n_cols = 2
n_rows = int(np.ceil(n_crypto / n_cols))

plt.figure(figsize=(14, 3 * n_rows))

for i, crypto in enumerate(crypto_names):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(future_dates, predictions[:, i], marker="o",  linewidth=2, label=crypto, color="tab:red")
    plt.title(f"Prediksi {crypto} 30 Hari ke Depan (Mulai 25 Juli 2025)")
    plt.xlabel("Tanggal")
    plt.ylabel("Harga (Normalized)")
    plt.xticks(rotation=45)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
